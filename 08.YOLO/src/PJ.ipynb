# %%
import cv2
import numpy as np
from sort import Sort
from ultralytics import YOLO

# Load YOLOv8 model
model = YOLO('yolov8n.pt')

# Initialize SORT tracker
tracker = Sort()
cap = cv2.VideoCapture("../../00.Data/08.YOLO/people_walk.mp4")

previous_positions = {}

def detect_objects(frame):
    boxes = model(frame)[0].boxes.xyxy.cpu().numpy()
    confidences = model(frame)[0].boxes.conf.cpu().numpy()
    detections = np.concatenate((boxes, confidences[:, np.newaxis]), axis=1)
    return detections

def calculate_speed_and_direction(prev_pos, current_pos, time_interval):
    dx = current_pos[0] - prev_pos[0]
    dy = current_pos[1] - prev_pos[1]
    distance = np.sqrt(dx**2 + dy**2)
    speed = distance / time_interval
    direction = np.arctan2(dy, dx) * 180 / np.pi  # in degrees
    return speed, direction

def draw_arrow_and_trajectory(frame, obj_id, center_x, center_y, prev_pos):
    positions_list = previous_positions.get(obj_id, None)

    if positions_list is None:
        positions_list = []
        previous_positions[obj_id] = positions_list

    if prev_pos:
        previous_positions[obj_id].append(prev_pos)
        for i in range(1, len(previous_positions[obj_id])):
            cv2.line(frame, previous_positions[obj_id][i-1], previous_positions[obj_id][i], (0, 255, 0), thickness=2)
        cv2.arrowedLine(frame, (int(prev_pos[0]), int(prev_pos[1])), (int(center_x), int(center_y)), (255, 0, 0), thickness=2, tipLength=0.1)

frame_rate = cap.get(cv2.CAP_PROP_FPS)
time_interval = 1.0 / frame_rate

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Ensure frame is in RGB format as expected by the model
    frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    detections = detect_objects(frame_rgb)
    dets = np.array([[x1, y1, x2, y2, conf] for x1, y1, x2, y2, conf in detections])
    tracked_objects = tracker.update(dets)

    for obj in tracked_objects:
        x1, y1, x2, y2, obj_id = obj[:5]
        center_x = (x1 + x2) / 2
        center_y = (y1 + y2) / 2
        current_pos = (center_x, center_y)

        prev_pos = previous_positions.get(obj_id, None)

        if prev_pos:
            speed, direction = calculate_speed_and_direction(prev_pos, current_pos, time_interval)
            cv2.putText(frame, f'ID: {int(obj_id)} Speed: {speed:.2f} Direction: {direction:.2f}',
                        (int(x1), int(y1) - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1)

        #draw_arrow_and_trajectory(frame, obj_id, center_x, center_y, prev_pos)

        previous_positions[obj_id] = current_pos

        cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (150, 50, 50), 2)

    cv2.imshow('Frame', frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 35 persons, 2 birds, 5.3ms
# Speed: 1.5ms preprocess, 5.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 2 birds, 5.8ms
# Speed: 5.1ms preprocess, 5.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 3 birds, 10.1ms
# Speed: 3.8ms preprocess, 10.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 3 birds, 10.6ms
# Speed: 1.5ms preprocess, 10.6ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 4 birds, 7.1ms
# Speed: 3.3ms preprocess, 7.1ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 4 birds, 8.6ms
# Speed: 2.7ms preprocess, 8.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 2 birds, 7.3ms
# Speed: 1.9ms preprocess, 7.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 2 birds, 9.2ms
# Speed: 3.6ms preprocess, 9.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 2 birds, 11.6ms
# Speed: 2.1ms preprocess, 11.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 2 birds, 10.7ms
# Speed: 4.8ms preprocess, 10.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 2 birds, 8.0ms
# Speed: 2.5ms preprocess, 8.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 2 birds, 10.1ms
# Speed: 1.5ms preprocess, 10.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 3 birds, 6.3ms
# Speed: 2.0ms preprocess, 6.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 3 birds, 5.7ms
# Speed: 1.9ms preprocess, 5.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 2 birds, 6.7ms
# Speed: 5.1ms preprocess, 6.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 2 birds, 7.5ms
# Speed: 2.6ms preprocess, 7.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 2 birds, 6.7ms
# Speed: 1.9ms preprocess, 6.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 2 birds, 5.1ms
# Speed: 1.6ms preprocess, 5.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 2 birds, 5.4ms
# Speed: 1.9ms preprocess, 5.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 2 birds, 5.5ms
# Speed: 1.3ms preprocess, 5.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 2 birds, 8.0ms
# Speed: 1.8ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 2 birds, 6.4ms
# Speed: 1.6ms preprocess, 6.4ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 2 birds, 7.4ms
# Speed: 2.0ms preprocess, 7.4ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 2 birds, 10.0ms
# Speed: 1.5ms preprocess, 10.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 2 birds, 8.3ms
# Speed: 2.3ms preprocess, 8.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 2 birds, 7.9ms
# Speed: 1.4ms preprocess, 7.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 3 birds, 7.6ms
# Speed: 2.0ms preprocess, 7.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 3 birds, 7.9ms
# Speed: 1.8ms preprocess, 7.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 4 birds, 8.1ms
# Speed: 1.7ms preprocess, 8.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 4 birds, 7.2ms
# Speed: 1.4ms preprocess, 7.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 4 birds, 7.4ms
# Speed: 1.8ms preprocess, 7.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 4 birds, 6.7ms
# Speed: 1.9ms preprocess, 6.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 3 birds, 9.0ms
# Speed: 2.5ms preprocess, 9.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 3 birds, 8.9ms
# Speed: 1.5ms preprocess, 8.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 2 birds, 10.0ms
# Speed: 2.2ms preprocess, 10.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 2 birds, 9.4ms
# Speed: 2.1ms preprocess, 9.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 2 birds, 8.1ms
# Speed: 1.9ms preprocess, 8.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 2 birds, 8.3ms
# Speed: 2.2ms preprocess, 8.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 2 birds, 8.8ms
# Speed: 4.0ms preprocess, 8.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 2 birds, 9.7ms
# Speed: 1.5ms preprocess, 9.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 2 birds, 1 dog, 10.0ms
# Speed: 2.1ms preprocess, 10.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 2 birds, 1 dog, 8.2ms
# Speed: 4.0ms preprocess, 8.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 1 bird, 1 dog, 7.7ms
# Speed: 3.5ms preprocess, 7.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 1 bird, 1 dog, 7.8ms
# Speed: 3.2ms preprocess, 7.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 1 bird, 1 dog, 8.3ms
# Speed: 1.9ms preprocess, 8.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 1 bird, 1 dog, 6.7ms
# Speed: 1.9ms preprocess, 6.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 1 bird, 1 dog, 7.5ms
# Speed: 1.8ms preprocess, 7.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 1 bird, 1 dog, 5.5ms
# Speed: 1.4ms preprocess, 5.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 1 bird, 1 dog, 6.8ms
# Speed: 5.1ms preprocess, 6.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 1 bird, 1 dog, 7.7ms
# Speed: 4.9ms preprocess, 7.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 1 bird, 1 dog, 6.6ms
# Speed: 8.8ms preprocess, 6.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 1 bird, 1 dog, 8.1ms
# Speed: 4.8ms preprocess, 8.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 1 bird, 7.3ms
# Speed: 1.8ms preprocess, 7.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 1 bird, 5.6ms
# Speed: 1.7ms preprocess, 5.6ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 1 bird, 7.9ms
# Speed: 1.5ms preprocess, 7.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 1 bird, 9.0ms
# Speed: 2.1ms preprocess, 9.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 1 bird, 9.0ms
# Speed: 2.3ms preprocess, 9.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 1 bird, 8.9ms
# Speed: 1.7ms preprocess, 8.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 1 bird, 8.8ms
# Speed: 2.3ms preprocess, 8.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 1 bird, 9.6ms
# Speed: 1.9ms preprocess, 9.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 1 bird, 8.5ms
# Speed: 3.7ms preprocess, 8.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 1 bird, 12.7ms
# Speed: 2.1ms preprocess, 12.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 2 birds, 5.6ms
# Speed: 1.7ms preprocess, 5.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 2 birds, 8.7ms
# Speed: 2.2ms preprocess, 8.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 2 birds, 8.5ms
# Speed: 2.2ms preprocess, 8.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 2 birds, 7.9ms
# Speed: 1.6ms preprocess, 7.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 1 bird, 5.2ms
# Speed: 1.9ms preprocess, 5.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 1 bird, 5.3ms
# Speed: 3.1ms preprocess, 5.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 2 birds, 5.4ms
# Speed: 1.9ms preprocess, 5.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 2 birds, 9.4ms
# Speed: 6.4ms preprocess, 9.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 1 bird, 9.7ms
# Speed: 2.8ms preprocess, 9.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 1 bird, 7.9ms
# Speed: 2.3ms preprocess, 7.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 1 bird, 8.9ms
# Speed: 3.9ms preprocess, 8.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 1 bird, 9.0ms
# Speed: 1.5ms preprocess, 9.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 2 birds, 7.4ms
# Speed: 2.2ms preprocess, 7.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 2 birds, 5.7ms
# Speed: 1.5ms preprocess, 5.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 persons, 1 bird, 8.8ms
# Speed: 1.9ms preprocess, 8.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 persons, 1 bird, 7.6ms
# Speed: 1.7ms preprocess, 7.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 2 birds, 6.9ms
# Speed: 5.6ms preprocess, 6.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 2 birds, 8.4ms
# Speed: 1.5ms preprocess, 8.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 2 birds, 6.1ms
# Speed: 1.9ms preprocess, 6.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 2 birds, 5.6ms
# Speed: 1.6ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 2 birds, 7.4ms
# Speed: 2.1ms preprocess, 7.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 2 birds, 6.4ms
# Speed: 2.7ms preprocess, 6.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 2 birds, 6.3ms
# Speed: 2.9ms preprocess, 6.3ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 2 birds, 9.4ms
# Speed: 4.4ms preprocess, 9.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 2 birds, 6.3ms
# Speed: 3.7ms preprocess, 6.3ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 2 birds, 15.5ms
# Speed: 4.3ms preprocess, 15.5ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 2 birds, 7.0ms
# Speed: 1.9ms preprocess, 7.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 2 birds, 5.4ms
# Speed: 2.8ms preprocess, 5.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 persons, 2 birds, 6.6ms
# Speed: 2.2ms preprocess, 6.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 persons, 2 birds, 5.6ms
# Speed: 2.6ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 1 bird, 7.8ms
# Speed: 2.2ms preprocess, 7.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 1 bird, 6.2ms
# Speed: 4.4ms preprocess, 6.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 1 bird, 6.7ms
# Speed: 5.6ms preprocess, 6.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 1 bird, 5.9ms
# Speed: 1.4ms preprocess, 5.9ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 1 bird, 1 dog, 8.2ms
# Speed: 2.0ms preprocess, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 1 bird, 1 dog, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 persons, 1 bird, 1 dog, 6.1ms
# Speed: 2.7ms preprocess, 6.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 persons, 1 bird, 1 dog, 6.4ms
# Speed: 1.6ms preprocess, 6.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 41 persons, 1 bird, 1 dog, 5.7ms
# Speed: 2.3ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 41 persons, 1 bird, 1 dog, 5.4ms
# Speed: 2.3ms preprocess, 5.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 40 persons, 1 bird, 1 dog, 6.8ms
# Speed: 1.6ms preprocess, 6.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 40 persons, 1 bird, 1 dog, 5.4ms
# Speed: 1.4ms preprocess, 5.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 1 bird, 1 dog, 6.9ms
# Speed: 2.0ms preprocess, 6.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 1 bird, 1 dog, 7.8ms
# Speed: 2.4ms preprocess, 7.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 2 birds, 1 dog, 9.6ms
# Speed: 3.1ms preprocess, 9.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 2 birds, 1 dog, 7.6ms
# Speed: 4.0ms preprocess, 7.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 1 bird, 1 dog, 7.2ms
# Speed: 1.8ms preprocess, 7.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 1 bird, 1 dog, 8.8ms
# Speed: 1.4ms preprocess, 8.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 39 persons, 1 bird, 8.9ms
# Speed: 3.4ms preprocess, 8.9ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 39 persons, 1 bird, 8.7ms
# Speed: 3.1ms preprocess, 8.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 persons, 1 bird, 5.7ms
# Speed: 3.0ms preprocess, 5.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 persons, 1 bird, 6.6ms
# Speed: 2.3ms preprocess, 6.6ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 1 bird, 1 horse, 7.8ms
# Speed: 2.1ms preprocess, 7.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 1 bird, 1 horse, 7.5ms
# Speed: 1.6ms preprocess, 7.5ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 1 bird, 7.9ms
# Speed: 2.0ms preprocess, 7.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 1 bird, 5.9ms
# Speed: 1.9ms preprocess, 5.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 39 persons, 1 bird, 7.3ms
# Speed: 1.7ms preprocess, 7.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 39 persons, 1 bird, 5.8ms
# Speed: 1.9ms preprocess, 5.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 1 bird, 6.2ms
# Speed: 2.4ms preprocess, 6.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 1 bird, 5.3ms
# Speed: 1.8ms preprocess, 5.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 39 persons, 1 bird, 10.5ms
# Speed: 5.2ms preprocess, 10.5ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 39 persons, 1 bird, 6.2ms
# Speed: 1.3ms preprocess, 6.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 7.5ms
# Speed: 2.0ms preprocess, 7.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 7.5ms
# Speed: 1.6ms preprocess, 7.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 7.9ms
# Speed: 2.0ms preprocess, 7.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 6.3ms
# Speed: 1.9ms preprocess, 6.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 1 bird, 7.6ms
# Speed: 3.5ms preprocess, 7.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 1 bird, 7.5ms
# Speed: 1.3ms preprocess, 7.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 persons, 1 bird, 6.5ms
# Speed: 4.3ms preprocess, 6.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 persons, 1 bird, 7.3ms
# Speed: 1.6ms preprocess, 7.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 39 persons, 1 bird, 5.9ms
# Speed: 5.6ms preprocess, 5.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 39 persons, 1 bird, 5.9ms
# Speed: 4.6ms preprocess, 5.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 persons, 1 bird, 1 dog, 12.1ms
# Speed: 2.8ms preprocess, 12.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 persons, 1 bird, 1 dog, 14.3ms
# Speed: 1.8ms preprocess, 14.3ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 persons, 1 bird, 1 dog, 8.7ms
# Speed: 2.5ms preprocess, 8.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 persons, 1 bird, 1 dog, 8.9ms
# Speed: 1.7ms preprocess, 8.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 1 bird, 1 dog, 7.9ms
# Speed: 3.2ms preprocess, 7.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 1 bird, 1 dog, 7.0ms
# Speed: 1.8ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 1 bird, 8.9ms
# Speed: 2.5ms preprocess, 8.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 1 bird, 7.1ms
# Speed: 1.6ms preprocess, 7.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 persons, 1 bird, 6.8ms
# Speed: 1.8ms preprocess, 6.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 persons, 1 bird, 5.6ms
# Speed: 1.8ms preprocess, 5.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 40 persons, 1 bird, 6.9ms
# Speed: 2.0ms preprocess, 6.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 40 persons, 1 bird, 5.0ms
# Speed: 2.1ms preprocess, 5.0ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 42 persons, 8.8ms
# Speed: 2.0ms preprocess, 8.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 42 persons, 8.7ms
# Speed: 1.7ms preprocess, 8.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 41 persons, 6.5ms
# Speed: 2.1ms preprocess, 6.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 41 persons, 7.9ms
# Speed: 2.1ms preprocess, 7.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 40 persons, 1 bird, 9.0ms
# Speed: 2.5ms preprocess, 9.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 40 persons, 1 bird, 9.7ms
# Speed: 2.2ms preprocess, 9.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 42 persons, 1 bird, 7.9ms
# Speed: 2.2ms preprocess, 7.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 42 persons, 1 bird, 7.0ms
# Speed: 1.8ms preprocess, 7.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 39 persons, 1 bird, 6.9ms
# Speed: 1.8ms preprocess, 6.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 39 persons, 1 bird, 5.8ms
# Speed: 1.5ms preprocess, 5.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 40 persons, 3 birds, 6.4ms
# Speed: 2.4ms preprocess, 6.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 40 persons, 3 birds, 5.8ms
# Speed: 1.6ms preprocess, 5.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 39 persons, 3 birds, 7.8ms
# Speed: 4.1ms preprocess, 7.8ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 39 persons, 3 birds, 9.8ms
# Speed: 2.6ms preprocess, 9.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 3 birds, 6.2ms
# Speed: 5.0ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 3 birds, 8.0ms
# Speed: 1.3ms preprocess, 8.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 3 birds, 6.8ms
# Speed: 1.8ms preprocess, 6.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 3 birds, 6.0ms
# Speed: 1.7ms preprocess, 6.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 39 persons, 1 bird, 9.3ms
# Speed: 2.1ms preprocess, 9.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 39 persons, 1 bird, 7.6ms
# Speed: 1.9ms preprocess, 7.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 40 persons, 1 bird, 6.5ms
# Speed: 2.0ms preprocess, 6.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 40 persons, 1 bird, 5.7ms
# Speed: 3.0ms preprocess, 5.7ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 41 persons, 2 birds, 8.2ms
# Speed: 3.5ms preprocess, 8.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 41 persons, 2 birds, 8.9ms
# Speed: 2.0ms preprocess, 8.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 39 persons, 1 horse, 8.0ms
# Speed: 2.2ms preprocess, 8.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 39 persons, 1 horse, 6.3ms
# Speed: 1.3ms preprocess, 6.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 39 persons, 7.2ms
# Speed: 4.5ms preprocess, 7.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 39 persons, 10.3ms
# Speed: 1.6ms preprocess, 10.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 7.1ms
# Speed: 6.5ms preprocess, 7.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 9.1ms
# Speed: 2.9ms preprocess, 9.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 8.0ms
# Speed: 7.0ms preprocess, 8.0ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 10.1ms
# Speed: 2.1ms preprocess, 10.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 7.8ms
# Speed: 5.0ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 11.4ms
# Speed: 4.3ms preprocess, 11.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 41 persons, 9.4ms
# Speed: 5.3ms preprocess, 9.4ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 41 persons, 8.8ms
# Speed: 2.0ms preprocess, 8.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 39 persons, 8.4ms
# Speed: 2.2ms preprocess, 8.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 39 persons, 6.5ms
# Speed: 1.6ms preprocess, 6.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 39 persons, 9.7ms
# Speed: 2.2ms preprocess, 9.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 39 persons, 7.3ms
# Speed: 1.5ms preprocess, 7.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 persons, 1 backpack, 7.8ms
# Speed: 4.4ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 persons, 1 backpack, 8.5ms
# Speed: 4.6ms preprocess, 8.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 9.3ms
# Speed: 2.4ms preprocess, 9.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 7.5ms
# Speed: 1.6ms preprocess, 7.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 9.5ms
# Speed: 2.1ms preprocess, 9.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 9.2ms
# Speed: 1.7ms preprocess, 9.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 8.2ms
# Speed: 2.5ms preprocess, 8.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 5.9ms
# Speed: 1.5ms preprocess, 5.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 1 dog, 8.7ms
# Speed: 2.2ms preprocess, 8.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 1 dog, 7.7ms
# Speed: 2.1ms preprocess, 7.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 9.8ms
# Speed: 2.1ms preprocess, 9.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 9.4ms
# Speed: 1.7ms preprocess, 9.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 8.4ms
# Speed: 2.6ms preprocess, 8.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 6.6ms
# Speed: 1.5ms preprocess, 6.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 1 backpack, 6.9ms
# Speed: 2.4ms preprocess, 6.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 1 backpack, 4.8ms
# Speed: 1.5ms preprocess, 4.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 2 backpacks, 9.1ms
# Speed: 2.6ms preprocess, 9.1ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 2 backpacks, 12.4ms
# Speed: 3.5ms preprocess, 12.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 1 bird, 1 backpack, 7.1ms
# Speed: 3.2ms preprocess, 7.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 1 bird, 1 backpack, 7.3ms
# Speed: 2.1ms preprocess, 7.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 1 bird, 7.6ms
# Speed: 1.8ms preprocess, 7.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 1 bird, 5.6ms
# Speed: 1.3ms preprocess, 5.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 1 bird, 6.9ms
# Speed: 1.8ms preprocess, 6.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 1 bird, 5.6ms
# Speed: 1.3ms preprocess, 5.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
