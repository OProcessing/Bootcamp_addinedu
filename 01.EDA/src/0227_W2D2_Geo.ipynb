# %%
import googlemaps
import pandas as pd
import folium
import numpy as np
from tqdm import tqdm

# %%
gmaps_key = "AIzaSyDBdDiJfzFkPizboGH4MO6LRDbNPDABAi8"
gmaps = googlemaps.Client(key=gmaps_key)

geocode = gmaps.geocode(address="1547 N. Wells st Chicago")
geocode

# %%
import json
print(json.dumps(geocode, indent=1))

# %%
lat = geocode[0].get("geometry")["location"]["lat"]
lng = geocode[0].get("geometry")["location"]["lng"]

# %%
df = pd.read_csv("../data/chicago_sandwiches_50.csv", index_col=0)
df.tail(10)

# %%
for idx, row in df.iterrows():
    print(str(idx) + ".\t" + row["Address"])

# %%
geocode = gmaps.geocode(address=". Multiple location")
geocode

# %%
lat_list = []
lng_list = []

for idx, row in tqdm(df.iterrows(), total=len(df.index)):
    geocode = gmaps.geocode(row["Address"] + ", Chicago")

    lat = geocode[0].get("geometry")["location"]["lat"] if len(geocode) > 0 else np.nan
    lng = geocode[0].get("geometry")["location"]["lng"] if len(geocode) > 0 else np.nan
    
    lat_list.append(lat)
    lng_list.append(lng)

    len(lat_list), len(lng_list)

# %%
df["lat"] = lat_list
df["lng"] = lng_list
df.head()

# %%
mapping = folium.Map(location=[lat_list[0], lng_list[0]], width="50%", height="50%", zoom_start=12)

for idx, row in df.iterrows():
    if row["lat"] == np.nan or row["lng"] == np.nan:
        continue
    else:
        folium.Marker([row["lat"], row["lng"]], popup=row["Cafe"]).add_to(mapping)

mapping
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b880ff70ee83ced5edc5aaed68b3b7d6 {
#                     position: relative;
#                     width: 50.0%;
#                     height: 50.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b880ff70ee83ced5edc5aaed68b3b7d6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b880ff70ee83ced5edc5aaed68b3b7d6 = L.map(
#                 &quot;map_b880ff70ee83ced5edc5aaed68b3b7d6&quot;,
#                 {
#                     center: [41.8955577, -87.6799673],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_75a05decba557e21a1f056e83c90f048 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_75a05decba557e21a1f056e83c90f048.addTo(map_b880ff70ee83ced5edc5aaed68b3b7d6);
#
#
#             var marker_f138e575d916439582392b58935e8eda = L.marker(
#                 [41.8955577, -87.6799673],
#                 {}
#             ).addTo(map_b880ff70ee83ced5edc5aaed68b3b7d6);
#
#
#         var popup_38bee2cecc234bf57fa164b103504327 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3ac2e09391a3a05f301238549d44629b = $(`&lt;div id=&quot;html_3ac2e09391a3a05f301238549d44629b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Old Oak Tap&lt;/div&gt;`)[0];
#                 popup_38bee2cecc234bf57fa164b103504327.setContent(html_3ac2e09391a3a05f301238549d44629b);
#
#
#
#         marker_f138e575d916439582392b58935e8eda.bindPopup(popup_38bee2cecc234bf57fa164b103504327)
#         ;
#
#
#
#
#             var marker_e3d7db175687cade5b1c5773214239c7 = L.marker(
#                 [41.8846392, -87.6475897],
#                 {}
#             ).addTo(map_b880ff70ee83ced5edc5aaed68b3b7d6);
#
#
#         var popup_773dde1c35f069894c21fd164098f3f4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a5204301bf2415a89c00688f00236026 = $(`&lt;div id=&quot;html_a5204301bf2415a89c00688f00236026&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Au Cheval&lt;/div&gt;`)[0];
#                 popup_773dde1c35f069894c21fd164098f3f4.setContent(html_a5204301bf2415a89c00688f00236026);
#
#
#
#         marker_e3d7db175687cade5b1c5773214239c7.bindPopup(popup_773dde1c35f069894c21fd164098f3f4)
#         ;
#
#
#
#
#             var marker_2d1070793aaa55b0c735bce52f0bdf7c = L.marker(
#                 [41.8905226, -87.6307834],
#                 {}
#             ).addTo(map_b880ff70ee83ced5edc5aaed68b3b7d6);
#
#
#         var popup_d32ed48ca571640c4281a2c871582c11 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_71303495bd8d218997484cb445d5f351 = $(`&lt;div id=&quot;html_71303495bd8d218997484cb445d5f351&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Xoco&lt;/div&gt;`)[0];
#                 popup_d32ed48ca571640c4281a2c871582c11.setContent(html_71303495bd8d218997484cb445d5f351);
#
#
#
#         marker_2d1070793aaa55b0c735bce52f0bdf7c.bindPopup(popup_d32ed48ca571640c4281a2c871582c11)
#         ;
#
#
#
#
#             var marker_768246691343ae53bd86c95055bdd2f4 = L.marker(
#                 [42.0583217, -87.6837479],
#                 {}
#             ).addTo(map_b880ff70ee83ced5edc5aaed68b3b7d6);
#
#
#         var popup_84351e6f81973e063067feeddbdf2e75 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3b6037789072a46e9bf59bd897e91fe8 = $(`&lt;div id=&quot;html_3b6037789072a46e9bf59bd897e91fe8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Al’s Deli&lt;/div&gt;`)[0];
#                 popup_84351e6f81973e063067feeddbdf2e75.setContent(html_3b6037789072a46e9bf59bd897e91fe8);
#
#
#
#         marker_768246691343ae53bd86c95055bdd2f4.bindPopup(popup_84351e6f81973e063067feeddbdf2e75)
#         ;
#
#
#
#
#             var marker_8bbaf2634d94fd164c6136ec5994b19c = L.marker(
#                 [41.8866036, -87.64853649999999],
#                 {}
#             ).addTo(map_b880ff70ee83ced5edc5aaed68b3b7d6);
#
#
#         var popup_b5a704d657d0feb93b974a442e953b5e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2362a763c0a7470d6f0cac3db131930f = $(`&lt;div id=&quot;html_2362a763c0a7470d6f0cac3db131930f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Publican Quality Meats&lt;/div&gt;`)[0];
#                 popup_b5a704d657d0feb93b974a442e953b5e.setContent(html_2362a763c0a7470d6f0cac3db131930f);
#
#
#
#         marker_8bbaf2634d94fd164c6136ec5994b19c.bindPopup(popup_b5a704d657d0feb93b974a442e953b5e)
#         ;
#
#
#
#
#             var marker_7d39f16ce343d81765a564713b470d22 = L.marker(
#                 [41.9001147, -87.62509969999999],
#                 {}
#             ).addTo(map_b880ff70ee83ced5ed
